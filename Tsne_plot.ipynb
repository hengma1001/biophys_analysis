# %%
import h5py 
import numpy as np

# %%
h5_file = h5py.File('./latent3d_fsp.h5', 'r')

# %%
h5_file.keys()
# Out:
# [u'RMSD', u'cm_predict', u'outliers']

# %%
tsne_h5 = h5py.File('./tsne_fsp.h5', 'r')

# %%
tsne_h5.keys()
# Out:
# [u'cm_predict', u'tsne']

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(10, 10)) 
ax.scatter(tsne_h5[u'tsne'][:,0], tsne_h5[u'tsne'][:,1], 
          c = h5_file['RMSD'][::10], cmap='jet')
